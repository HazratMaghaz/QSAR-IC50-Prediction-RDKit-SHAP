# %% [markdown]
# # 08 — Applicability Domain / Williams Plot
#
# This notebook runs an applicability-domain style diagnostic based on residuals and model predictions.

# %%
import subprocess, sys
cmd = [sys.executable, "../scripts/applicability_domain.py"]
result = subprocess.run(cmd, capture_output=True, text=True)
print(result.stdout)
if result.stderr:
    print("STDERR:
", result.stderr)

# %%
from pathlib import Path
from IPython.display import Image, display

fig = Path("../results/figures/williams_plot_demo.png")
if fig.exists():
    display(Image(filename=str(fig)))
else:
    print("Figure not found:", fig)
