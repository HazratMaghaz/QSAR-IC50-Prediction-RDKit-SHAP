# %% [markdown]
# # 05 — New Compound Prediction
#
# This notebook demonstrates how a trained QSAR model can be used for new compound prediction.
#
# At the moment, the legacy fingerprint workflow uses precomputed fingerprints. Prediction for new molecules requires generating the same fingerprint type for the new compounds before applying the trained model.

# %%
from pathlib import Path

print("New compounds file:", Path("../data/new_compounds.csv"))
print("Prediction script:", Path("../scripts/predict_new_compounds.py"))
print("Best model:", Path("../results/models/best_qsar_model.joblib"))

# %% [markdown]
# ## Important
#
# For real new-compound prediction, the input molecules must be converted into the same feature/fingerprint format that the selected best model was trained on. This is why keeping a consistent descriptor-generation pipeline is important.
