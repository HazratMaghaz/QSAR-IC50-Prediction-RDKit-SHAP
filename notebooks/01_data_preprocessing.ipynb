# %% [markdown]
# # 01 - Data Preprocessing
#
# Load the demo QSAR dataset and convert IC50 values to pIC50.

# %%
import pandas as pd
from pathlib import Path

df = pd.read_csv('../data/sample_qsar_dataset.csv')
df.head()

# %%
df[['compound_id','smiles','ic50_uM','pic50']].head()
