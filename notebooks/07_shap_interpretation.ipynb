# %% [markdown]
# # 07 — SHAP Interpretation
#
# This notebook is for interpreting the selected best QSAR model.
#
# For a full SHAP workflow, the selected model and its training matrix must be loaded consistently.

# %%
from pathlib import Path
print("Model folder:", Path("../results/models"))
print("Figures folder:", Path("../results/figures"))
print("SHAP script:", Path("../scripts/shap_analysis.py"))

# %% [markdown]
# ## Next improvement
#
# The next advanced improvement is to save the exact training feature matrix used by the best model, then use it for SHAP summary plotting. This will make the interpretation fully reproducible.
