# %% [markdown]
# # 02 - RDKit Descriptor Generation
#
# Generate basic molecular descriptors from SMILES.

# %%
# Run from repository root for the script version:
# python scripts/generate_descriptors.py

import pandas as pd
pd.read_csv('../data/sample_qsar_dataset.csv').head()
