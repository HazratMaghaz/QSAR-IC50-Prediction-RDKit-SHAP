# %% [markdown]
# # 04 — SHAP Interpretation
#
# This notebook is reserved for model interpretation.
#
# SHAP interpretation is most useful after choosing a final model and descriptor/fingerprint set. For tree-based models, SHAP can help identify the features contributing most to predicted pIC50.

# %%
from pathlib import Path

model_path = Path("../results/models/best_qsar_model.joblib")
print("Best model exists:", model_path.exists())

# The main SHAP script is available at:
print("Script:", Path("../scripts/shap_analysis.py"))

# %%
# Optional: run only after confirming dependencies are installed
# import subprocess, sys
# subprocess.run([sys.executable, "../scripts/shap_analysis.py"], check=True)

# %% [markdown]
# ## Notes
#
# If SHAP is not installed, install the project environment first.
#
# For conda users:
#
# ```bash
# conda env create -f environment.yml
# conda activate qsar-ml
# ```
